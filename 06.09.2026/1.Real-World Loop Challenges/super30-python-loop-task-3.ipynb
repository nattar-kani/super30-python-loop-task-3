# %%
transactions = [1200, 450, 800, 1500, 2300, 700, 100]

# %%
sum = 0
for i in transactions:
    sum = sum + i

print("Total transaction value:", sum)
# Out:
# Total transaction value: 7050

# %%
highest = transactions[0]
lowest = transactions[0]

for transaction in transactions:
    if transaction > highest:
        highest = transaction

    if transaction < lowest:
        lowest = transaction

print("Highest transaction:", highest)
print("Lowest transaction:", lowest)
# Out:
# Highest transaction: 2300
# Lowest transaction: 100

# %%
temperatures = [32, 35, 28, 40, 38, 31, 42]

# %%
sum = 0
for i in transactions:
    sum = sum + i

avg = sum / len(transactions)
print(f"Average temperature: {avg:.2f}")
# Out:
# Average temperature: 1007.14

# %%
marks = [78, 92, 45, 67, 88, 53, 99]

# %%
above_90 = 0
between_75n89 = 0
between_50n74 = 0
below_50 = 0

for mark in marks:

    if mark >= 90:
        above_90 += 1

    elif mark >= 75:
        between_75n89 += 1

    elif mark >= 50:
        between_50n74 += 1

    else:
        below_50 += 1

print("90+:", above_90)
print("75 to 89:", between_75n89)
print("50 to 74:", between_50n74)
print("Below 50:", below_50)
# Out:
# 90+: 2
# 75 to 89: 2
# 50 to 74: 2
# Below 50: 1

# %%
password = "secret-key"

# %%
for attempt in range(1,4):
    pwd = input("enter password")

    if pwd == password:
        print("Login successful!")
        break

    else:
        print("Incorrect password.")

else:
    print("Account locked. Maximum attempts exceeded.")
# Out:
# Incorrect password.
# Incorrect password.
# Incorrect password.
# Account locked. Maximum attempts exceeded.

# %%
products = {
    "Laptop": 55000,
    "Phone": 30000,
    "Headphones": 2000,
    "Mouse": 700,
    "Keyboard": 1500
}

# %%
for product, price in products.items():

    if price > 2000:
        print(product, ":", price)
# Out:
# Laptop : 55000
# Phone : 30000

# %%
numbers = []

# %%
for i in range(10):
    number = int(input(f"Enter number {i + 1}: "))
    numbers.append(number)

print("Numbers:", numbers)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 for i in range(10):
# ----> 2     number = int(input(f"Enter number {i + 1}: "))
#       3     numbers.append(number)
#       4
#       5 print("Numbers:", numbers)
#
# ValueError: invalid literal for int() with base 10: 'hui'

# %%
text = input("Enter a string: ")
frequency = {}

for character in text:

    if character in frequency:
        frequency[character] += 1
    else:
        frequency[character] = 1

for character, count in frequency.items():
    print(character, "->", count)
# Out:
# m -> 1
# i -> 2
# n -> 2
# o -> 1

# %%
marks = [78, 92, 45, 67, 88, 53, 99]

# %%
largest = None
second_largest = None

for mark in marks:

    if largest is None or mark > largest:
        second_largest = largest
        largest = mark

    elif mark != largest and (
        second_largest is None or mark > second_largest
    ):
        second_largest = mark

# %%
print("Largest:", largest)
print("Second largest:", second_largest)
# Out:
# Largest: 99
# Second largest: 92

# %%
text = input("Enter a string: ")

# %%
reversed_text = ""

# %%
for character in text:
    reversed_text = character + reversed_text

if text == reversed_text:
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# Palindrome

# %%
for i in range(1, 6):

    for j in range(1, i + 1):
        print(j, end="")

    print()
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %%
balance = 100_000

# %%
def check_balance():
    print(f"Current balance: ₹{balance}")

# %%
def deposit():
    global balance

    amount = float(input("Enter deposit amount: ₹"))

    if amount <= 0:
        print("Invalid deposit amount.")
        return

    balance += amount
    print(f"₹{amount:.2f} deposited successfully.")

# %%
def withdraw():
    global balance

    amount = float(input("Enter withdrawal amount: ₹"))

    if amount <= 0:
        print("Invalid withdrawal amount.")
        return

    if amount > balance:
        print("Insufficient balance.")
        return

    balance -= amount
    print(f"₹{amount:.2f} withdrawn successfully.")

# %%
def atm():
    while True:

        print("\nATM MENU")
        print("1. Check Balance")
        print("2. Deposit Money")
        print("3. Withdraw Money")
        print("4. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            check_balance()

        elif choice == "2":
            deposit()

        elif choice == "3":
            withdraw()

        elif choice == "4":
            print("Thank you for using the ATM.")
            break

        else:
            print("Invalid choice. Please try again.")

# %%
atm()
# Out:
# ===== ATM MENU =====
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Current balance: ₹100000
#
# ===== ATM MENU =====
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# ₹4.00 withdrawn successfully.
#
# ===== ATM MENU =====
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Thank you for using the ATM.
